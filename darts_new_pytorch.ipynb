# %%
# !git status
# Out:
# On branch darts_efficient_mobilenet
# Your branch is up to date with 'origin/darts_efficient_mobilenet'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   searchs/fashionmnist/best.pth.tar
# 	modified:   searchs/fashionmnist/checkpoint.pth.tar
# 	modified:   searchs/fashionmnist/fashionmnist.log
# 	modified:   searchs/fashionmnist/plots/EP01-normal
# 	modified:   searchs/fashionmnist/plots/EP01-normal.png
# 	modified:   searchs/fashionmnist/plots/EP01-reduce
# 	modified:   searchs/fashionmnist/plots/EP01-reduce.png
# 	modified:   searchs/fashionmnist/plots/EP02-normal
# 	modified:   searchs/fashionmnist/plots/EP02-normal.png
# 	modified:   searchs/fashionmnist/plots/EP02-reduce
# 	modified:   searchs/fashionmnist/plots/EP02-reduce.png
# 	modified:   searchs/fashionmnist/plots/EP03-normal
# 	modified:   searchs/fashionmnist/plots/EP03-normal.png
# 	modified:   searchs/fashionmnist/plots/EP03-reduce
# ...

# %%
# !git add .

# %%
# !git commit -m "searched using fasion mnist and mbconv fusedmbconv dsconv"
# Out:
# [darts_efficient_mobilenet 0d5c390] searched using fasion mnist and mbconv fusedmbconv dsconv
#  205 files changed, 5694 insertions(+), 46 deletions(-)
#  rewrite searchs/fashionmnist/plots/EP01-normal.png (99%)
#  rewrite searchs/fashionmnist/plots/EP01-reduce.png (99%)
#  rewrite searchs/fashionmnist/plots/EP02-normal.png (98%)
#  rewrite searchs/fashionmnist/plots/EP02-reduce.png (99%)
#  rewrite searchs/fashionmnist/plots/EP03-normal.png (98%)
#  rewrite searchs/fashionmnist/plots/EP03-reduce.png (99%)
#  create mode 100644 searchs/fashionmnist/plots/EP04-normal
#  create mode 100644 searchs/fashionmnist/plots/EP04-normal.png
#  create mode 100644 searchs/fashionmnist/plots/EP04-reduce
#  create mode 100644 searchs/fashionmnist/plots/EP04-reduce.png
#  create mode 100644 searchs/fashionmnist/plots/EP05-normal
#  create mode 100644 searchs/fashionmnist/plots/EP05-normal.png
#  create mode 100644 searchs/fashionmnist/plots/EP05-reduce
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-4-4996ee3d8d09> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.9/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.9/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     119   """Internal helper to mount Google Drive."""
#     120   if _os.path.exists('/var/colab/mp'):
# ...

# %%
# %cd /content/pt.darts
# Out:
# /content/pt.darts

# %%
# !git push
# Out:
# Enumerating objects: 229, done.
# Counting objects: 100% (229/229), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (209/209), done.
# Writing objects: 100% (210/210), 14.11 MiB | 7.60 MiB/s, done.
# Total 210 (delta 175), reused 0 (delta 0)
# remote: Resolving deltas: 100% (175/175), completed with 2 local objects.
# To https://github.com/HAJEKEL/pt.darts.git
#    aa87489..0d5c390  darts_efficient_mobilenet -> darts_efficient_mobilenet

# %%
# !git remote set-url origin https://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@github.com/HAJEKEL/pt.darts.git

# %%
# Run this if you're in a Colab
# !git clone https://github.com/HAJEKEL/pt.darts
# Out:
# Cloning into 'pt.darts'...
# remote: Enumerating objects: 271, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 271 (delta 52), reused 115 (delta 51), pack-reused 152
# Receiving objects: 100% (271/271), 88.86 MiB | 15.10 MiB/s, done.
# Resolving deltas: 100% (119/119), done.

# %%
# !git pull
# Out:
# From https://github.com/HAJEKEL/pt.darts
#  * [new branch]      darts_efficient_mobilenet -> origin/darts_efficient_mobilenet
# Already up to date.

# %%
# !git checkout darts_efficient_mobilenet
# Out:
# Branch 'darts_efficient_mobilenet' set up to track remote branch 'darts_efficient_mobilenet' from 'origin'.
# Switched to a new branch 'darts_efficient_mobilenet'

# %%
# !git reset d4bc7646e55e299fc6313dc9a692f157e076661a
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git config --global user.email "hendrikjekel@gmail.com"
# !git config --global user.name "Henk Jekel"

# %%
# !git checkout master
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !ls /content/pt.darts/
# Out:
# architect.py  data		    LICENSE	__pycache__	  search.py
# assets	      demistify_mnist1d.py  models	README.md	  searchs
# augment.py    Dockerfile	    preproc.py	requirements.txt  utils.py
# config.py     genotypes.py	    pt.darts	scripts		  visualize.py

# %%
# %cd /content/pt.darts
# Out:
# /content/pt.darts

# %%
# !pwd
# Out:
# /content/pt.darts

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 6.8 MB/s eta 0:00:00
# ...

# %%
# !python search.py --name fashionmnist --dataset fashionmnist --workers 2
# Out:
# 04/27 12:22:50 PM |
# 04/27 12:22:50 PM | Parameters:
# 04/27 12:22:50 PM | ALPHA_LR=0.0003
# 04/27 12:22:50 PM | ALPHA_WEIGHT_DECAY=0.001
# 04/27 12:22:50 PM | BATCH_SIZE=64
# 04/27 12:22:50 PM | DATA_PATH=./data/
# 04/27 12:22:50 PM | DATASET=fashionmnist
# 04/27 12:22:50 PM | EPOCHS=50
# 04/27 12:22:50 PM | GPUS=[0]
# 04/27 12:22:50 PM | INIT_CHANNELS=16
# 04/27 12:22:50 PM | LAYERS=8
# 04/27 12:22:50 PM | NAME=fashionmnist
# 04/27 12:22:50 PM | PATH=searchs/fashionmnist
# 04/27 12:22:50 PM | PLOT_PATH=searchs/fashionmnist/plots
# 04/27 12:22:50 PM | PRINT_FREQ=50
# 04/27 12:22:50 PM | SEED=2
# 04/27 12:22:50 PM | W_GRAD_CLIP=5.0
# 04/27 12:22:50 PM | W_LR=0.025
# 04/27 12:22:50 PM | W_LR_MIN=0.001
# 04/27 12:22:50 PM | W_MOMENTUM=0.9
# 04/27 12:22:50 PM | W_WEIGHT_DECAY=0.0003
# 04/27 12:22:50 PM | WORKERS=2
# 04/27 12:22:50 PM |
# 04/27 12:22:50 PM | Logger is set - training start
# ...
