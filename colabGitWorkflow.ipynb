# %%
#To get into the google drive folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#getting into the google drive folder which has the same contents as the remote repository
# %cd /content/gdrive/My Drive/efficientnet_darts
# Out:
# /content/gdrive/My Drive/efficientnet_darts

# %%
#If it is the first time, we need to initialize the google drive folder as a git repository
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/efficientnet_darts/.git/

# %%
#Define these variable's they will be used later
token = '' #Github->settings->developer settings->PAT->MAKE SURE TO GIVE ALL REQUIRED PERMISSIONS WHEN GENERATING THE TOKEN
username = "" #github username
repo = "" #repo name

# %%
#run in case there is already an origin that is not the origin that we are trying to make
# !git remote rm origin

# %%
#Make the origin
# !git remote add origin https://{username}:{token}@github.com/{username}/{repo}

# %%
#Configure your user name and email
# !git config --global user.email 'github mail'
# !git config --global user.name 'github username'

# %%
#Add the changes to the version control system
# !git add .

# %%
#View the changes
# !git status
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
#commit the changes
# !git commit -m "Changed name to darts_search and added comments on how to use it"
# Out:
# [main 57e502c] Changed name to darts_search and added comments on how to use it
#  2 files changed, 1 insertion(+), 1 deletion(-)
#  delete mode 100644 darts_new_pytorch.ipynb
#  create mode 100644 darts_search.ipynb

# %%
#In case there are changes in the remote that you want to use
# !git pull
# Out:
# Already up to date.

# %%
#Go to the branch you want to be in
# !git checkout main
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Switched to a new branch 'main'

# %%
#push the changes to the branch
# !git push --set-upstream origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 4.90 KiB | 1.22 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/HAJEKEL/EfficientNetV2_paper_reproduction
#    6dbe90c..57e502c  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
